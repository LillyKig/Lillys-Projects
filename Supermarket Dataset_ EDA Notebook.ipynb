# %% [markdown]
# <h2 align=center>Exploratory Data Analysis With Python and Pandas</h2>
# <img src="logo.png">

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Link to data source: https://www.kaggle.com/aungpyaeap/supermarket-sales
#
# **Context**
#
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data.
#
# **Data Dictionary**
#
# 1. ***Invoice id:*** Computer generated sales slip invoice identification number
#
# 2. ***Branch:*** Branch of supercenter (3 branches are available identified by A, B and C).
#
# 3. ***City:*** Location of supercenters
#
# 4. ***Customer type:*** Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# 5. ***Gender:*** Gender type of customer
#
# 6. ***Product line:*** General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# 7. ***Unit price:*** Price of each product in USD
#
# 8. ***Quantity:*** Number of products purchased by customer
#
# 9. ***Tax:*** 5% tax fee for customer buying
#
# 10. ***Total:*** Total price including tax
#
# 11. ***Date:*** Date of purchase (Record available from January 2019 to March 2019)
#
# 12. ***Time:*** Purchase time (10am to 9pm)
#
# 13. ***Payment:*** Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# 14. ***COGS:*** Cost of goods sold
#
# 15. ***Gross margin percentage:*** Gross margin percentage
#
# 16. ***Gross income:*** Gross income
#
# 17. ***Rating:*** Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ### Task 1: Initial Data Exploration

# %%
df= pd.read_csv("supermarket_sales.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date']
# Out:
# 0       1/5/2019
# 1       3/8/2019
# 2       3/3/2019
# 3      1/27/2019
# 4       2/8/2019
#          ...
# 995    1/29/2019
# 996     3/2/2019
# 997     2/9/2019
# 998    2/22/2019
# 999    2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# ### Task 2: Univariate Analysis

# %% [markdown]
# **Question 1:** What does the distribution of customer ratings looks like? Is it skewed?
#
# **Answer** The distribution of customer ratings looks relatively uniform and there doesnt seem to be any skew in the left or right direction.

# %%
sns.histplot(df['Rating'])
plt.axvline(x=np.mean(df['Rating']),c='red',ls='--',label='mean')
plt.axvline(x=np.percentile(df['Rating'],25),c='green',ls='--', label= '25-75th percentile')
plt.axvline(x=np.percentile(df['Rating'],75),c='green',ls='--')
plt.legend()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Unit price'}>,
#         <Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Tax 5%'}>],
#        [<Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'cogs'}>,
#         <Axes: title={'center': 'gross margin percentage'}>],
#        [<Axes: title={'center': 'gross income'}>,
#         <Axes: title={'center': 'Rating'}>, <Axes: >]], dtype=object)

# %% [markdown]
# **Question 2:** Do aggregate sales numbers differ by much between branches, payment styles?
#
# **Answer** Yes, Branch A has the most number of sales and the most used payment style is ewallet

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
sns.countplot(x="Branch", data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
sns.countplot(x="Payment", data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %% [markdown]
# ### Task 3: Bivariate Analysis

# %% [markdown]
# **Question 3:** Is there a relationship between Variables?
#
# **Answer** The trend line is flat when comparing Rating to gross income therefore there is no relationship. The median gross income in Branch C is higher compared to Branch A and B. The median gross income is slightly higher in female than men.

# %%
sns.regplot(x="Rating", y="gross income", data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='gross income'>

# %%
sns.boxplot(x="Branch", y="gross income", data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.boxplot(x="Gender", y="gross income", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# **Question 4:** Is there a noticeable time trend in gross income?
#
# **Answer**There is no noticable time trend in gross income.It varies around the same mean but this is only 3months data.

# %%
df.head()
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
df.drop(columns='Invoice ID', inplace=True)

# %%
df.head()
# Out:
#            Branch       City Customer type  Gender            Product line  \
# Date
# 2019-01-05      A     Yangon        Member  Female       Health and beauty
# 2019-03-08      C  Naypyitaw        Normal  Female  Electronic accessories
# 2019-03-03      A     Yangon        Normal    Male      Home and lifestyle
# 2019-01-27      A     Yangon        Member    Male       Health and beauty
# 2019-02-08      A     Yangon        Normal    Male       Sports and travel
#
#             Unit price  Quantity   Tax 5%     Total   Time      Payment  \
# Date
# 2019-01-05       74.69         7  26.1415  548.9715  13:08      Ewallet
# 2019-03-08       15.28         5   3.8200   80.2200  10:29         Cash
# 2019-03-03       46.33         7  16.2155  340.5255  13:23  Credit card
# 2019-01-27       58.22         8  23.2880  489.0480  20:33      Ewallet
# 2019-02-08       86.31         7  30.2085  634.3785  10:37      Ewallet
#
#               cogs  gross margin percentage  gross income  Rating
# ...

# %%
numeric_columns = df.select_dtypes(include='number')
grouped = numeric_columns.groupby(df.index).mean()
grouped
# Out:
#             Unit price  Quantity     Tax 5%       Total        cogs  \
# Date
# 2019-01-01   54.995833  6.750000  18.830083  395.431750  376.601667
# 2019-01-02   44.635000  6.000000  11.580375  243.187875  231.607500
# 2019-01-03   59.457500  4.625000  12.369813  259.766062  247.396250
# 2019-01-04   51.743333  5.333333  12.886417  270.614750  257.728333
# 2019-01-05   61.636667  4.583333  14.034458  294.723625  280.689167
# ...                ...       ...        ...         ...         ...
# 2019-03-26   42.972308  4.000000   7.188692  150.962538  143.773846
# 2019-03-27   56.841000  4.500000  13.822950  290.281950  276.459000
# 2019-03-28   45.525000  4.800000  10.616200  222.940200  212.324000
# 2019-03-29   66.346250  6.750000  23.947875  502.905375  478.957500
# 2019-03-30   67.408182  6.090909  19.424500  407.914500  388.490000
#
#             gross margin percentage  gross income    Rating
# Date
# 2019-01-01                 4.761905     18.830083  6.583333
# ...

# %%
sns.lineplot(x=numeric_columns.groupby(df.index).mean().index, 
             y=numeric_columns.groupby(df.index).mean()["gross income"])
# Out:
# <Axes: xlabel='Date', ylabel='gross income'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\wanjl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Task 4: Dealing With Duplicate Rows and Missing Values

# %%
df.head()
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ### Task 5: Correlation Analysis

# %%
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Helpful Links

# %% [markdown]
# 1. More visualizations: https://www.data-to-viz.com/
# 2. Seaborn gallery: https://seaborn.pydata.org/examples/index.html
# 3. Pandas profiling documentation: https://pypi.org/project/pandas-profiling/
